# %% [markdown]
# dynamic feature analysis

# %%
import pandas as pd
import numpy as np

# %%
column_name = ['A_pos_peak_time', 'MAX_pos_peak_time', 'MIN_pos_peak_time', 'A_neg_peak_time', 'MAX_neg_peak_time', 'MIN_neg_peak_time',
 'A_close time', 'MAX_close time', 'MIN_close time', 'A_open time', 'MAX_open time', 'MIN_open time', 'A_blink time', 
 'MAX_blink time', 'MIN_blink time', 'A_peak ratio', 'MAX_peak ratio', 'MIN_peak ratio', 'A_peak dist ratio', 'MAX_peak dist ratio', 
 'MIN_peak dist ratio', 'A_area ratio', 'MAX_area ratio', 'MIN_area ratio', 'Label']

# %%
#define converts(字典)  
def Name_label(s):
    
    return int(s) - 1

# %%
csv_path = '../gen_data/dynamic_features.csv'
data_path = '../gen_data/dynamic_feature-2-26.data'
data = np.loadtxt(data_path, dtype=float, delimiter=',', converters={24:Name_label})

df = pd.DataFrame(data, columns=column_name)

df.to_csv(csv_path, index=False, sep=',')

# %%
data = pd.read_csv(csv_path)
data.head()
# Out:
#    A_pos_peak_time  MAX_pos_peak_time  MIN_pos_peak_time  A_neg_peak_time  \
# 0             36.8               49.2               71.2            146.8
# 1             38.4               47.6               78.8            172.8
# 2             37.2               52.0               81.2            157.2
# 3             33.6               47.6               74.4            159.6
# 4             35.2               48.8               76.8            156.0
#
#    MAX_neg_peak_time  MIN_neg_peak_time  A_close time  MAX_close time  \
# 0              218.0               2.78          0.38            1.24
# 1              251.6               2.38          0.35            1.05
# 2              238.4               2.47          0.40            1.09
# 3              234.0               2.63          0.38            1.15
# 4              232.8               2.65          0.39            1.12
#
#    MIN_close time  A_open time  ...  A_peak ratio  MAX_peak ratio  \
# 0            44.0         58.0  ...          1.46            34.0
# 1            50.0         56.0  ...          1.28            32.0
# 2            54.0         68.0  ...          1.25            32.0
# 3            36.0         58.0  ...          1.25            30.0
# 4            42.0         58.0  ...          1.23            32.0
#
#    MIN_peak ratio  A_peak dist ratio  MAX_peak dist ratio  \
# 0            38.0               68.0                134.0
# 1            38.0               70.0                156.0
# 2            44.0               66.0                152.0
# 3            40.0               68.0                148.0
# 4            40.0               70.0                150.0
#
#    MIN_peak dist ratio  A_area ratio  MAX_area ratio  MIN_area ratio  Label
# 0                204.0          2.20            0.34            1.06    0.0
# 1                228.0          0.90            0.25            0.60    0.0
# 2                222.0          2.33            0.34            1.02    0.0
# 3                222.0          2.46            0.33            1.08    0.0
# 4                224.0          2.42            0.35            1.01    0.0
#
# [5 rows x 25 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 25 columns):
# A_pos_peak_time        263 non-null float64
# MAX_pos_peak_time      263 non-null float64
# MIN_pos_peak_time      263 non-null float64
# A_neg_peak_time        263 non-null float64
# MAX_neg_peak_time      263 non-null float64
# MIN_neg_peak_time      263 non-null float64
# A_close time           263 non-null float64
# MAX_close time         263 non-null float64
# MIN_close time         263 non-null float64
# A_open time            263 non-null float64
# MAX_open time          263 non-null float64
# MIN_open time          263 non-null float64
# A_blink time           263 non-null float64
# MAX_blink time         263 non-null float64
# MIN_blink time         263 non-null float64
# A_peak ratio           263 non-null float64
# MAX_peak ratio         263 non-null float64
# MIN_peak ratio         263 non-null float64
# A_peak dist ratio      263 non-null float64
# MAX_peak dist ratio    263 non-null float64
# MIN_peak dist ratio    263 non-null float64
# A_area ratio           263 non-null float64
# MAX_area ratio         263 non-null float64
# MIN_area ratio         263 non-null float64
# Label                  263 non-null float64
# dtypes: float64(25)
# memory usage: 51.4 KB

# %%
data.describe()
# Out:
#        A_pos_peak_time  MAX_pos_peak_time  MIN_pos_peak_time  A_neg_peak_time  \
# count       263.000000         263.000000         263.000000       263.000000
# mean         44.906464          64.684411         105.262357       162.667681
# std          22.431240         100.296933         127.617359       100.219759
# min          30.800000          32.400000          66.800000        93.600000
# 25%          38.800000          42.000000          78.200000       134.800000
# 50%          42.400000          47.600000          84.800000       152.400000
# 75%          47.400000          56.800000          96.000000       165.600000
# max         386.800000        1390.800000        1896.800000      1491.200000
#
#        MAX_neg_peak_time  MIN_neg_peak_time  A_close time  MAX_close time  \
# count         263.000000         263.000000    263.000000      263.000000
# mean          267.930038           2.530228      0.406844        1.577338
# std           226.421834           0.510749      0.086176        0.565763
# min           160.400000           0.560000      0.270000        0.810000
# 25%           218.400000           2.225000      0.360000        1.260000
# 50%           236.400000           2.550000      0.400000        1.440000
# 75%           257.000000           2.800000      0.430000        1.740000
# max          3388.000000           4.860000      0.840000        7.470000
#
#        MIN_close time  A_open time  ...  A_peak ratio  MAX_peak ratio  \
# count      263.000000   263.000000  ...    263.000000      263.000000
# mean        60.372624   102.555133  ...      2.080837       36.288973
# std        107.457350   226.690384  ...      2.219427        5.941842
# min         34.000000    36.000000  ...      1.070000       20.000000
# 25%         44.000000    50.000000  ...      1.400000       32.000000
# 50%         50.000000    58.000000  ...      1.680000       36.000000
# 75%         58.000000    72.000000  ...      2.060000       40.000000
# max       1758.000000  2058.000000  ...     32.190000       52.000000
#
#        MIN_peak ratio  A_peak dist ratio  MAX_peak dist ratio  \
# count      263.000000         263.000000           263.000000
# mean        41.117871          81.901141           131.832700
# std         24.183408          94.478267            33.102699
# min         22.000000          52.000000            60.000000
# 25%         34.000000          68.000000           112.000000
# 50%         38.000000          74.000000           134.000000
# 75%         44.000000          82.000000           150.000000
# max        384.000000        1594.000000           440.000000
#
#        MIN_peak dist ratio  A_area ratio  MAX_area ratio  MIN_area ratio  \
# count           263.000000    263.000000      263.000000      263.000000
# mean            221.787072      2.023194        0.342243        1.272243
# std             176.288323      0.608048        0.060329        0.326963
# min             124.000000      0.190000        0.180000        0.170000
# 25%             190.000000      1.790000        0.290000        1.090000
# 50%             212.000000      2.140000        0.350000        1.270000
# 75%             230.000000      2.375000        0.380000        1.430000
# max            3014.000000      4.010000        0.610000        2.190000
#
#             Label
# count  263.000000
# mean     3.912548
# std      3.090856
# min      0.000000
# 25%      1.000000
# 50%      4.000000
# 75%      7.000000
# max      9.000000
#
# [8 rows x 25 columns]

# %%
def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = "../myplot/" + fig_id + "." + fig_extension
    print("Saving figure", fig_id)
    if tight_layout:
        
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
data.hist(bins=50, figsize=(20,15))
save_fig("attribute_histogram_plots")
plt.show()
# Out:
# Saving figure attribute_histogram_plots

# %% [markdown]
# # 相关性分析

# %%
corr_matrix = data.corr()
corr_matrix["Label"].sort_values(ascending=False)
# Out:
# Label                  1.000000
# MAX_peak ratio         0.242459
# MAX_blink time         0.144644
# MAX_close time         0.142896
# A_peak ratio           0.111361
# MIN_neg_peak_time      0.109658
# A_pos_peak_time        0.093964
# MIN_area ratio         0.064174
# A_area ratio           0.052850
# MAX_peak dist ratio    0.028506
# A_peak dist ratio      0.018295
# MIN_close time         0.017658
# MIN_peak dist ratio    0.011860
# MIN_blink time         0.010979
# A_neg_peak_time        0.005635
# MIN_peak ratio        -0.000321
# MAX_neg_peak_time     -0.002566
# MIN_open time         -0.007667
# MIN_pos_peak_time     -0.008977
# A_blink time          -0.021028
# A_close time          -0.022535
# MAX_pos_peak_time     -0.024888
# A_open time           -0.026971
# MAX_open time         -0.032130
# MAX_area ratio        -0.060555
# Name: Label, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ["Label", "MAX_peak ratio", "MAX_blink time", "MAX_close time", "A_peak ratio"]
scatter_matrix(data[attributes], figsize=(20, 15))
save_fig("correlation_plots")
# Out:
# Saving figure correlation_plots
